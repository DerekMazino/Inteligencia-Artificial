# %% [markdown]
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/banner_IA.png"  width="1000px" height="200px">
#
# # **Taller 05:  Deep neural networks**
#
# ## **Outline**
#
# 1. [Ejercicio 1. DNN-classification](#eje1)
# 2. [Ejercicio 2. DNN-classification](#eje2)
# 3. [Ejercicio 3. DNN-Regression](#eje3)

# %%
#@title 1. MONTAR EL DRIVE **student** { display-mode: "form" }
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/UIS/IA/ai-uis-student/talleres20202')

print(os.getcwd())
# !chmod 777 convert_ipynb.sh run utils/*
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/UIS/IA/ai-uis-student/talleres20202

# %% [markdown]
# ---
# #### - Usted debe ejecutar **TODAS** las celdas de tipo **CODE**. De lo contrario, sus respuestas no serán procesadas correctamente.
#
# #### - Para este notebook es recomendable usar la **GPU**. Por favor verifique que este habilitada la GPU en `Editar-> Configuración del notebook->Acelerador de hardware (Opcion GPU)`
# ---

# %% [markdown]
# # **Ejercicio 1: DNN classification**  <a name="eje1"></a>
#
# Escriba una función que reciba un conjunto de datos etiquetados (X,y) y entrene una red neuronal, con la siguiente configuración:
# - Una capa de entrada con la dimensión de cada muestra $x_i$
# - Cuatro capas intermedias  de 128, 64, 32, 16 neuronas y activaciones `elu`
# - Una capa de salida _softmax_ con el número de clases $y$. Las clases cada vez que se llama pueden cambiar su número.
#
# - Las redes neuronales deben ser entrenadas con unpitimizador SGD,  epochs=50,  batch_size=32, y regla de minimización: `sparse_categorical_crossentropy`
#
# - La función debe retornar las etiquetas estimadas para el x_test, el accuracy obtenido en test y el modelo entrenado.

# %%
#@title **2172969**
#@markdown No modifique las dos últimas lineas

def fun_51012821(X_train, X_test, y_train, y_test):
  import numpy as np
  import tensorflow as tf
  from tensorflow import keras
  dnn1 = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape=(X_train[0].shape) ),
    tf.keras.layers.Dense(128, activation=tf.nn.elu),
    tf.keras.layers.Dense(64, activation=tf.nn.elu),
    tf.keras.layers.Dense(32, activation=tf.nn.elu),
    tf.keras.layers.Dense(16, activation=tf.nn.elu),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
    ])   
  dnn1.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
  dnn1.fit(X_train, y_train, epochs=50, batch_size=32)
  test_loss, test_acc = dnn1.evaluate(X_test, y_test)
  yest1 = dnn1.predict(X_test)
  yest1 = np.argmax(yest1, axis = 1) 
  return yest1, test_acc, dnn1



import urllib.parse, inspect
src51012821 = urllib.parse.quote_plus(inspect.getsource(fun_51012821))

# %%
#@title **verifique su respuesta**
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras


tf.random.set_seed(23)
np.random.seed(23)

X, y = make_classification(n_samples= 10000, n_features=100, n_redundant=0,\
                             n_classes=5, n_clusters_per_class=5,n_informative=32)

test_size = 0.1
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size)
print(X.shape, y.shape, X_train.shape,y_train.shape)

yest1, test_acc, dnn1 = fun_51012821(X_train, X_test, y_train, y_test)

print("accuracy obtenido: ", test_acc)
print(y_test.shape, yest1.shape)

fig = plt.figure(figsize=(15,5))
ax = fig.add_subplot(1, 2, 1)
ax.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=y_test, s=25)
ax = fig.add_subplot(1, 2, 2)
ax.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=yest1, s=25)
# Out:
# (10000, 100) (10000,) (9000, 100) (9000,)
# Epoch 1/50
# 282/282 [==============================] - 1s 1ms/step - loss: 1.7263 - accuracy: 0.2831
# Epoch 2/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3644 - accuracy: 0.4345
# Epoch 3/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.2511 - accuracy: 0.4938
# Epoch 4/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.1595 - accuracy: 0.5526
# Epoch 5/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.0672 - accuracy: 0.5846
# Epoch 6/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9776 - accuracy: 0.6280
# Epoch 7/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8819 - accuracy: 0.6765
# Epoch 8/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8226 - accuracy: 0.6960
# Epoch 9/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7591 - accuracy: 0.7210
# Epoch 10/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6983 - accuracy: 0.7482
# Epoch 11/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6439 - accuracy: 0.7673
# Epoch 12/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5982 - accuracy: 0.7859
# Epoch 13/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5461 - accuracy: 0.8036
# Epoch 14/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5116 - accuracy: 0.8197
# Epoch 15/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.8373
# Epoch 16/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.4188 - accuracy: 0.8565
# Epoch 17/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3906 - accuracy: 0.8667
# Epoch 18/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3595 - accuracy: 0.8814
# Epoch 19/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8916
# Epoch 20/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8985
# Epoch 21/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.9127
# Epoch 22/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2418 - accuracy: 0.9238
# Epoch 23/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2139 - accuracy: 0.9331
# Epoch 24/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2008 - accuracy: 0.9367
# Epoch 25/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1650 - accuracy: 0.9524
# Epoch 26/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9597
# Epoch 27/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1274 - accuracy: 0.9660
# Epoch 28/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9704
# Epoch 29/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0986 - accuracy: 0.9780
# Epoch 30/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9781
# Epoch 31/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0732 - accuracy: 0.9871
# Epoch 32/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0598 - accuracy: 0.9916
# Epoch 33/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9948
# Epoch 34/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0368 - accuracy: 0.9971
# Epoch 35/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0293 - accuracy: 0.9994
# Epoch 36/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0245 - accuracy: 0.9994
# Epoch 37/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0238 - accuracy: 0.9995
# Epoch 38/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0178 - accuracy: 0.9999
# Epoch 39/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 0.9998
# Epoch 40/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.9999
# Epoch 41/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 42/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 43/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 44/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 45/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 46/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 47/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 48/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 49/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 50/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# 32/32 [==============================] - 0s 1ms/step - loss: 2.3756 - accuracy: 0.6520
# accuracy obtenido:  0.6520000100135803
# (1000,) (1000,)

# %%
#@title **Evalue su respuesta.**
# !./run CHECK_SOLUTION PS5_51012821 $src51012821
# Out:
# 2021-02-05 02:21:26.189331: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# (1000, 20) (1000,) (700, 20) (700,)
# 2021-02-05 02:21:28.154626: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 02:21:28.155625: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-05 02:21:28.166340: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-05 02:21:28.166406: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e55c31f2382c): /proc/driver/nvidia/version does not exist
# 2021-02-05 02:21:28.166731: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-02-05 02:21:28.166910: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 02:21:28.271482: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-05 02:21:28.271909: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1999995000 Hz
# Epoch 1/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.7182 - accuracy: 0.2029
# Epoch 2/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.5615 - accuracy: 0.2627
# Epoch 3/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.5166 - accuracy: 0.2779
# Epoch 4/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.4682 - accuracy: 0.3387
# Epoch 5/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.4495 - accuracy: 0.3320
# Epoch 6/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.4201 - accuracy: 0.3894
# Epoch 7/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.4152 - accuracy: 0.3696
# Epoch 8/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3772 - accuracy: 0.4232
# Epoch 9/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3698 - accuracy: 0.4048
# Epoch 10/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3881 - accuracy: 0.4000
# Epoch 11/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3748 - accuracy: 0.4202
# Epoch 12/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3541 - accuracy: 0.4291
# Epoch 13/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3543 - accuracy: 0.4596
# Epoch 14/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3028 - accuracy: 0.4611
# Epoch 15/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3466 - accuracy: 0.4534
# Epoch 16/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3142 - accuracy: 0.4731
# Epoch 17/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3256 - accuracy: 0.4512
# Epoch 18/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3090 - accuracy: 0.4469
# Epoch 19/50
# 22/22 [==============================] - 0s 2ms/step - loss: 1.3201 - accuracy: 0.4660
# Epoch 20/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2970 - accuracy: 0.4941
# Epoch 21/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2979 - accuracy: 0.4787
# Epoch 22/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2740 - accuracy: 0.4781
# Epoch 23/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.3039 - accuracy: 0.4910
# Epoch 24/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2471 - accuracy: 0.5023
# Epoch 25/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2818 - accuracy: 0.4795
# Epoch 26/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2427 - accuracy: 0.5092
# Epoch 27/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2404 - accuracy: 0.4942
# Epoch 28/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2419 - accuracy: 0.5182
# Epoch 29/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2439 - accuracy: 0.5037
# Epoch 30/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2352 - accuracy: 0.5102
# Epoch 31/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2476 - accuracy: 0.4901
# Epoch 32/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2193 - accuracy: 0.5230
# Epoch 33/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2180 - accuracy: 0.5008
# Epoch 34/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.2621 - accuracy: 0.4758
# Epoch 35/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1808 - accuracy: 0.5285
# Epoch 36/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1774 - accuracy: 0.5294
# Epoch 37/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1935 - accuracy: 0.5359
# Epoch 38/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1873 - accuracy: 0.5327
# Epoch 39/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1584 - accuracy: 0.5655
# Epoch 40/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1554 - accuracy: 0.5686
# Epoch 41/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1619 - accuracy: 0.5489
# Epoch 42/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1886 - accuracy: 0.5403
# Epoch 43/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1914 - accuracy: 0.5245
# Epoch 44/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1310 - accuracy: 0.5658
# Epoch 45/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1661 - accuracy: 0.5434
# Epoch 46/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1250 - accuracy: 0.5471
# Epoch 47/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.0691 - accuracy: 0.5924
# Epoch 48/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1302 - accuracy: 0.5708
# Epoch 49/50
# 22/22 [==============================] - 0s 1ms/step - loss: 1.0918 - accuracy: 0.6199
# Epoch 50/50
# 22/22 [==============================] - 0s 2ms/step - loss: 1.1227 - accuracy: 0.5799
# 10/10 [==============================] - 0s 959us/step - loss: 1.4046 - accuracy: 0.4300
# evaluation result CORRECT

# %% [markdown]
# # **Ejercicio 2: DNN classification**  <a name="eje2"></a>
#
# Observe el comportamiento de las arquitecturas neuronales, condicionadas con diferentes parametros para el entrenamiento. Escriba una función que cree instancias de la red neuronal (escrita dentro de la función) y la entrene con los siguientes tres parametros de aprendizaje $\alpha = [0.1, 0.001, 0.00001]$, respectivamente.
#
# - Las redes neuronales deben ser entrenadas con unpitimizador SGD,  epochs=50,  batch_size=32, y regla de minimización: `sparse_categorical_crossentropy`
#
# - La función debe retornar la historia de entrenamiento `fit` y los tres modelos entrenados

# %%
#@title **2172969**
#@markdown No modifique las dos últimas lineas

def fun_52012821(X_train, X_test, y_train, y_test):
  import numpy as np
  import tensorflow as tf
  from tensorflow import keras
  def model_dnn():
    dnn = keras.models.Sequential([
                                    keras.layers.Flatten( input_shape= (X_train[0].shape)),
                                    keras.layers.Dense(64, activation=tf.nn.relu),
                                    keras.layers.Dense(64, activation=tf.nn.relu),
                                    keras.layers.Dense(3, activation=tf.nn.softmax)
                                    ])
    return dnn
  
  dnn1_lr1 = model_dnn()
  dnn1_lr1.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

  dnn1_lr2 = model_dnn()
  dnn1_lr2.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
  
  dnn1_lr3 = model_dnn()
  dnn1_lr3.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.00001), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

  hist1 = dnn1_lr1.fit(X_train,
          y_train, epochs=50,
          batch_size=32,
          validation_data=(X_test, y_test))
  hist2 = dnn1_lr2.fit(X_train,
          y_train, epochs=50,
          batch_size=32,
          validation_data=(X_test, y_test))
  hist3 = dnn1_lr3.fit(X_train,
          y_train, epochs=50,
          batch_size=32,
          validation_data=(X_test, y_test))
  return hist1, hist2, hist3, dnn1_lr1, dnn1_lr2, dnn1_lr3



import urllib.parse, inspect
src52012821 = urllib.parse.quote_plus(inspect.getsource(fun_52012821))

# %%
#@title **verifique su respuesta**
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras


tf.random.set_seed(23)
np.random.seed(23)

X, y = make_classification(n_samples= 10000, n_features=100, n_redundant=0,\
                             n_classes=3, n_clusters_per_class=5,n_informative=32)

test_size = 0.1
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size)
print(X.shape, y.shape, X_train.shape,y_train.shape)

hist1, hist2, hist3, dnn1_lr1, dnn1_lr2, dnn1_lr3 = fun_52012821(X_train, X_test, y_train, y_test)

plt.plot(hist1.history['loss'], label='train loss dn1');
plt.plot(hist2.history['loss'], label='train loss dn2');
plt.plot(hist3.history['loss'], label='train loss dn3');
plt.legend(); plt.show();

plt.plot(hist1.history['accuracy'], label='train acc dn1');
plt.plot(hist2.history['accuracy'], label='train acc dn1');
plt.plot(hist3.history['accuracy'], label='train acc dn1');
plt.legend(); plt.show()
# Out:
# (10000, 100) (10000,) (9000, 100) (9000,)
# Epoch 1/50
# 282/282 [==============================] - 1s 2ms/step - loss: 0.9402 - accuracy: 0.5829 - val_loss: 0.6524 - val_accuracy: 0.7110
# Epoch 2/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5385 - accuracy: 0.7778 - val_loss: 0.5566 - val_accuracy: 0.7820
# Epoch 3/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8453 - val_loss: 0.5562 - val_accuracy: 0.7790
# Epoch 4/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8631 - val_loss: 0.5626 - val_accuracy: 0.7910
# Epoch 5/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2903 - accuracy: 0.8874 - val_loss: 0.5758 - val_accuracy: 0.7900
# Epoch 6/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.9116 - val_loss: 0.5545 - val_accuracy: 0.8070
# Epoch 7/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1990 - accuracy: 0.9266 - val_loss: 0.5381 - val_accuracy: 0.8150
# Epoch 8/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1686 - accuracy: 0.9373 - val_loss: 0.6042 - val_accuracy: 0.8120
# Epoch 9/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1530 - accuracy: 0.9413 - val_loss: 0.5949 - val_accuracy: 0.8190
# Epoch 10/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1385 - accuracy: 0.9505 - val_loss: 0.5732 - val_accuracy: 0.8250
# Epoch 11/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1078 - accuracy: 0.9608 - val_loss: 0.5585 - val_accuracy: 0.8420
# Epoch 12/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9622 - val_loss: 0.6474 - val_accuracy: 0.8200
# Epoch 13/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.1009 - accuracy: 0.9642 - val_loss: 0.7415 - val_accuracy: 0.8220
# Epoch 14/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9673 - val_loss: 0.7020 - val_accuracy: 0.8240
# Epoch 15/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0792 - accuracy: 0.9695 - val_loss: 0.7874 - val_accuracy: 0.8370
# Epoch 16/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0881 - accuracy: 0.9679 - val_loss: 0.8308 - val_accuracy: 0.8310
# Epoch 17/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0737 - accuracy: 0.9704 - val_loss: 0.7434 - val_accuracy: 0.8530
# Epoch 18/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9693 - val_loss: 0.7970 - val_accuracy: 0.8360
# Epoch 19/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0516 - accuracy: 0.9826 - val_loss: 0.8435 - val_accuracy: 0.8360
# Epoch 20/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9827 - val_loss: 0.8711 - val_accuracy: 0.8380
# Epoch 21/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.8900 - val_accuracy: 0.8480
# Epoch 22/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.9036 - val_accuracy: 0.8560
# Epoch 23/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.8561 - val_accuracy: 0.8570
# Epoch 24/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8563 - val_accuracy: 0.8580
# Epoch 25/50
# 282/282 [==============================] - 1s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8675 - val_accuracy: 0.8610
# Epoch 26/50
# 282/282 [==============================] - 0s 1ms/step - loss: 9.3034e-04 - accuracy: 1.0000 - val_loss: 0.8771 - val_accuracy: 0.8630
# Epoch 27/50
# 282/282 [==============================] - 0s 1ms/step - loss: 7.8938e-04 - accuracy: 1.0000 - val_loss: 0.8852 - val_accuracy: 0.8620
# Epoch 28/50
# 282/282 [==============================] - 0s 1ms/step - loss: 7.1038e-04 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.8610
# Epoch 29/50
# 282/282 [==============================] - 0s 1ms/step - loss: 6.4274e-04 - accuracy: 1.0000 - val_loss: 0.8989 - val_accuracy: 0.8600
# Epoch 30/50
# 282/282 [==============================] - 0s 1ms/step - loss: 5.9760e-04 - accuracy: 1.0000 - val_loss: 0.9057 - val_accuracy: 0.8600
# Epoch 31/50
# 282/282 [==============================] - 0s 1ms/step - loss: 5.4841e-04 - accuracy: 1.0000 - val_loss: 0.9115 - val_accuracy: 0.8590
# Epoch 32/50
# 282/282 [==============================] - 0s 1ms/step - loss: 5.2900e-04 - accuracy: 1.0000 - val_loss: 0.9181 - val_accuracy: 0.8570
# Epoch 33/50
# 282/282 [==============================] - 0s 1ms/step - loss: 4.7713e-04 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.8590
# Epoch 34/50
# 282/282 [==============================] - 0s 1ms/step - loss: 4.7536e-04 - accuracy: 1.0000 - val_loss: 0.9267 - val_accuracy: 0.8590
# Epoch 35/50
# 282/282 [==============================] - 0s 1ms/step - loss: 4.2572e-04 - accuracy: 1.0000 - val_loss: 0.9308 - val_accuracy: 0.8600
# Epoch 36/50
# 282/282 [==============================] - 0s 1ms/step - loss: 4.2878e-04 - accuracy: 1.0000 - val_loss: 0.9354 - val_accuracy: 0.8590
# Epoch 37/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.9976e-04 - accuracy: 1.0000 - val_loss: 0.9402 - val_accuracy: 0.8590
# Epoch 38/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.6971e-04 - accuracy: 1.0000 - val_loss: 0.9441 - val_accuracy: 0.8590
# Epoch 39/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.4935e-04 - accuracy: 1.0000 - val_loss: 0.9465 - val_accuracy: 0.8600
# Epoch 40/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.4210e-04 - accuracy: 1.0000 - val_loss: 0.9503 - val_accuracy: 0.8570
# Epoch 41/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.2375e-04 - accuracy: 1.0000 - val_loss: 0.9542 - val_accuracy: 0.8570
# Epoch 42/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.0740e-04 - accuracy: 1.0000 - val_loss: 0.9582 - val_accuracy: 0.8570
# Epoch 43/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.0117e-04 - accuracy: 1.0000 - val_loss: 0.9609 - val_accuracy: 0.8570
# Epoch 44/50
# 282/282 [==============================] - 0s 1ms/step - loss: 3.0054e-04 - accuracy: 1.0000 - val_loss: 0.9642 - val_accuracy: 0.8570
# Epoch 45/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.7338e-04 - accuracy: 1.0000 - val_loss: 0.9670 - val_accuracy: 0.8580
# Epoch 46/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.4703e-04 - accuracy: 1.0000 - val_loss: 0.9698 - val_accuracy: 0.8580
# Epoch 47/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.4685e-04 - accuracy: 1.0000 - val_loss: 0.9716 - val_accuracy: 0.8590
# Epoch 48/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.4460e-04 - accuracy: 1.0000 - val_loss: 0.9755 - val_accuracy: 0.8580
# Epoch 49/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.3563e-04 - accuracy: 1.0000 - val_loss: 0.9778 - val_accuracy: 0.8580
# Epoch 50/50
# 282/282 [==============================] - 0s 1ms/step - loss: 2.2951e-04 - accuracy: 1.0000 - val_loss: 0.9801 - val_accuracy: 0.8570
# Epoch 1/50
# 282/282 [==============================] - 1s 2ms/step - loss: 1.4675 - accuracy: 0.3299 - val_loss: 1.2099 - val_accuracy: 0.3870
# Epoch 2/50
# 282/282 [==============================] - 1s 2ms/step - loss: 1.1769 - accuracy: 0.3848 - val_loss: 1.1146 - val_accuracy: 0.4430
# Epoch 3/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.0880 - accuracy: 0.4330 - val_loss: 1.0624 - val_accuracy: 0.4670
# Epoch 4/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.0398 - accuracy: 0.4695 - val_loss: 1.0264 - val_accuracy: 0.4980
# Epoch 5/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9978 - accuracy: 0.5019 - val_loss: 0.9996 - val_accuracy: 0.5220
# Epoch 6/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9697 - accuracy: 0.5146 - val_loss: 0.9777 - val_accuracy: 0.5360
# Epoch 7/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9528 - accuracy: 0.5416 - val_loss: 0.9606 - val_accuracy: 0.5410
# Epoch 8/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9302 - accuracy: 0.5537 - val_loss: 0.9434 - val_accuracy: 0.5540
# Epoch 9/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9137 - accuracy: 0.5659 - val_loss: 0.9303 - val_accuracy: 0.5640
# Epoch 10/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8849 - accuracy: 0.5896 - val_loss: 0.9168 - val_accuracy: 0.5670
# Epoch 11/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8756 - accuracy: 0.5938 - val_loss: 0.9048 - val_accuracy: 0.5770
# Epoch 12/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8655 - accuracy: 0.5936 - val_loss: 0.8946 - val_accuracy: 0.5880
# Epoch 13/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8552 - accuracy: 0.6046 - val_loss: 0.8852 - val_accuracy: 0.5970
# Epoch 14/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8434 - accuracy: 0.6095 - val_loss: 0.8759 - val_accuracy: 0.6020
# Epoch 15/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8287 - accuracy: 0.6243 - val_loss: 0.8662 - val_accuracy: 0.6130
# Epoch 16/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8134 - accuracy: 0.6360 - val_loss: 0.8578 - val_accuracy: 0.6170
# Epoch 17/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8141 - accuracy: 0.6362 - val_loss: 0.8506 - val_accuracy: 0.6210
# Epoch 18/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.8041 - accuracy: 0.6359 - val_loss: 0.8434 - val_accuracy: 0.6240
# Epoch 19/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7862 - accuracy: 0.6583 - val_loss: 0.8359 - val_accuracy: 0.6280
# Epoch 20/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7791 - accuracy: 0.6528 - val_loss: 0.8289 - val_accuracy: 0.6320
# Epoch 21/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7784 - accuracy: 0.6592 - val_loss: 0.8220 - val_accuracy: 0.6360
# Epoch 22/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7609 - accuracy: 0.6697 - val_loss: 0.8161 - val_accuracy: 0.6350
# Epoch 23/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7559 - accuracy: 0.6721 - val_loss: 0.8103 - val_accuracy: 0.6390
# Epoch 24/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7387 - accuracy: 0.6773 - val_loss: 0.8037 - val_accuracy: 0.6520
# Epoch 25/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7362 - accuracy: 0.6816 - val_loss: 0.7978 - val_accuracy: 0.6600
# Epoch 26/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7366 - accuracy: 0.6782 - val_loss: 0.7952 - val_accuracy: 0.6560
# Epoch 27/50
# 282/282 [==============================] - 1s 2ms/step - loss: 0.7292 - accuracy: 0.6826 - val_loss: 0.7874 - val_accuracy: 0.6620
# Epoch 28/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7246 - accuracy: 0.6826 - val_loss: 0.7818 - val_accuracy: 0.6680
# Epoch 29/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7082 - accuracy: 0.6911 - val_loss: 0.7775 - val_accuracy: 0.6660
# Epoch 30/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7125 - accuracy: 0.6895 - val_loss: 0.7715 - val_accuracy: 0.6710
# Epoch 31/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.7048 - accuracy: 0.7038 - val_loss: 0.7676 - val_accuracy: 0.6720
# Epoch 32/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.7059 - val_loss: 0.7620 - val_accuracy: 0.6740
# Epoch 33/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6806 - accuracy: 0.7102 - val_loss: 0.7580 - val_accuracy: 0.6710
# Epoch 34/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.7076 - val_loss: 0.7531 - val_accuracy: 0.6740
# Epoch 35/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6648 - accuracy: 0.7212 - val_loss: 0.7500 - val_accuracy: 0.6760
# Epoch 36/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6725 - accuracy: 0.7149 - val_loss: 0.7457 - val_accuracy: 0.6800
# Epoch 37/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6641 - accuracy: 0.7205 - val_loss: 0.7402 - val_accuracy: 0.6790
# Epoch 38/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6619 - accuracy: 0.7235 - val_loss: 0.7354 - val_accuracy: 0.6780
# Epoch 39/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6606 - accuracy: 0.7205 - val_loss: 0.7327 - val_accuracy: 0.6870
# Epoch 40/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6441 - accuracy: 0.7299 - val_loss: 0.7270 - val_accuracy: 0.6820
# Epoch 41/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6293 - accuracy: 0.7362 - val_loss: 0.7230 - val_accuracy: 0.6840
# Epoch 42/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6318 - accuracy: 0.7383 - val_loss: 0.7198 - val_accuracy: 0.6890
# Epoch 43/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6325 - accuracy: 0.7384 - val_loss: 0.7162 - val_accuracy: 0.6920
# Epoch 44/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6285 - accuracy: 0.7411 - val_loss: 0.7117 - val_accuracy: 0.6890
# Epoch 45/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6097 - accuracy: 0.7497 - val_loss: 0.7077 - val_accuracy: 0.6940
# Epoch 46/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.6185 - accuracy: 0.7495 - val_loss: 0.7044 - val_accuracy: 0.6940
# Epoch 47/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5991 - accuracy: 0.7574 - val_loss: 0.7002 - val_accuracy: 0.7020
# Epoch 48/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5942 - accuracy: 0.7615 - val_loss: 0.6982 - val_accuracy: 0.7020
# Epoch 49/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.7589 - val_loss: 0.6939 - val_accuracy: 0.7010
# Epoch 50/50
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.7607 - val_loss: 0.6900 - val_accuracy: 0.7070
# Epoch 1/50
# 282/282 [==============================] - 1s 2ms/step - loss: 1.7578 - accuracy: 0.3258 - val_loss: 1.7378 - val_accuracy: 0.3030
# Epoch 2/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.7051 - accuracy: 0.3321 - val_loss: 1.7142 - val_accuracy: 0.3000
# Epoch 3/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.6983 - accuracy: 0.3325 - val_loss: 1.6919 - val_accuracy: 0.2960
# Epoch 4/50
# 282/282 [==============================] - 1s 2ms/step - loss: 1.6830 - accuracy: 0.3239 - val_loss: 1.6709 - val_accuracy: 0.2960
# Epoch 5/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.6703 - accuracy: 0.3239 - val_loss: 1.6512 - val_accuracy: 0.2980
# Epoch 6/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.6545 - accuracy: 0.3186 - val_loss: 1.6325 - val_accuracy: 0.2990
# Epoch 7/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.6080 - accuracy: 0.3254 - val_loss: 1.6150 - val_accuracy: 0.2990
# Epoch 8/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5829 - accuracy: 0.3385 - val_loss: 1.5985 - val_accuracy: 0.3000
# Epoch 9/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.6116 - accuracy: 0.3197 - val_loss: 1.5830 - val_accuracy: 0.2970
# Epoch 10/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5803 - accuracy: 0.3181 - val_loss: 1.5685 - val_accuracy: 0.2980
# Epoch 11/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5433 - accuracy: 0.3271 - val_loss: 1.5550 - val_accuracy: 0.2980
# Epoch 12/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5495 - accuracy: 0.3283 - val_loss: 1.5423 - val_accuracy: 0.2930
# Epoch 13/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5294 - accuracy: 0.3221 - val_loss: 1.5305 - val_accuracy: 0.2950
# Epoch 14/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5016 - accuracy: 0.3243 - val_loss: 1.5194 - val_accuracy: 0.2930
# Epoch 15/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.5067 - accuracy: 0.3221 - val_loss: 1.5091 - val_accuracy: 0.2920
# Epoch 16/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4892 - accuracy: 0.3270 - val_loss: 1.4994 - val_accuracy: 0.2920
# Epoch 17/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4710 - accuracy: 0.3313 - val_loss: 1.4904 - val_accuracy: 0.2920
# Epoch 18/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4516 - accuracy: 0.3314 - val_loss: 1.4820 - val_accuracy: 0.2900
# Epoch 19/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4534 - accuracy: 0.3233 - val_loss: 1.4741 - val_accuracy: 0.2910
# Epoch 20/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4432 - accuracy: 0.3185 - val_loss: 1.4667 - val_accuracy: 0.2900
# Epoch 21/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4484 - accuracy: 0.3200 - val_loss: 1.4598 - val_accuracy: 0.2910
# Epoch 22/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4437 - accuracy: 0.3306 - val_loss: 1.4533 - val_accuracy: 0.2940
# Epoch 23/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4404 - accuracy: 0.3246 - val_loss: 1.4472 - val_accuracy: 0.2930
# Epoch 24/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4221 - accuracy: 0.3272 - val_loss: 1.4414 - val_accuracy: 0.2900
# Epoch 25/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4160 - accuracy: 0.3252 - val_loss: 1.4360 - val_accuracy: 0.2920
# Epoch 26/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4303 - accuracy: 0.3248 - val_loss: 1.4309 - val_accuracy: 0.2910
# Epoch 27/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4142 - accuracy: 0.3243 - val_loss: 1.4261 - val_accuracy: 0.2970
# Epoch 28/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4123 - accuracy: 0.3249 - val_loss: 1.4215 - val_accuracy: 0.2960
# Epoch 29/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.4114 - accuracy: 0.3204 - val_loss: 1.4171 - val_accuracy: 0.2970
# Epoch 30/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3969 - accuracy: 0.3251 - val_loss: 1.4130 - val_accuracy: 0.2990
# Epoch 31/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3846 - accuracy: 0.3316 - val_loss: 1.4090 - val_accuracy: 0.3030
# Epoch 32/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3944 - accuracy: 0.3150 - val_loss: 1.4052 - val_accuracy: 0.3000
# Epoch 33/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3893 - accuracy: 0.3267 - val_loss: 1.4016 - val_accuracy: 0.3010
# Epoch 34/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3787 - accuracy: 0.3229 - val_loss: 1.3981 - val_accuracy: 0.3000
# Epoch 35/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3728 - accuracy: 0.3247 - val_loss: 1.3947 - val_accuracy: 0.3030
# Epoch 36/50
# 282/282 [==============================] - 1s 2ms/step - loss: 1.3609 - accuracy: 0.3326 - val_loss: 1.3914 - val_accuracy: 0.3020
# Epoch 37/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3695 - accuracy: 0.3224 - val_loss: 1.3883 - val_accuracy: 0.3020
# Epoch 38/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3698 - accuracy: 0.3210 - val_loss: 1.3853 - val_accuracy: 0.3030
# Epoch 39/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3634 - accuracy: 0.3236 - val_loss: 1.3823 - val_accuracy: 0.3050
# Epoch 40/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3531 - accuracy: 0.3332 - val_loss: 1.3794 - val_accuracy: 0.3060
# Epoch 41/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3560 - accuracy: 0.3331 - val_loss: 1.3766 - val_accuracy: 0.3050
# Epoch 42/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3482 - accuracy: 0.3314 - val_loss: 1.3739 - val_accuracy: 0.3100
# Epoch 43/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3537 - accuracy: 0.3269 - val_loss: 1.3712 - val_accuracy: 0.3110
# Epoch 44/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3415 - accuracy: 0.3379 - val_loss: 1.3686 - val_accuracy: 0.3120
# Epoch 45/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3453 - accuracy: 0.3359 - val_loss: 1.3660 - val_accuracy: 0.3130
# Epoch 46/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3322 - accuracy: 0.3346 - val_loss: 1.3635 - val_accuracy: 0.3130
# Epoch 47/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3427 - accuracy: 0.3345 - val_loss: 1.3610 - val_accuracy: 0.3110
# Epoch 48/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3575 - accuracy: 0.3264 - val_loss: 1.3585 - val_accuracy: 0.3130
# Epoch 49/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3377 - accuracy: 0.3277 - val_loss: 1.3561 - val_accuracy: 0.3130
# Epoch 50/50
# 282/282 [==============================] - 0s 1ms/step - loss: 1.3408 - accuracy: 0.3352 - val_loss: 1.3538 - val_accuracy: 0.3140
# <tensorflow.python.keras.callbacks.History object at 0x7fe2fa56ac88>

# %%
#@title **Evalue su respuesta.**
# !./run CHECK_SOLUTION PS5_52012821 $src52012821
# Out:
# 2021-02-05 22:59:14.570569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# (1000, 20) (1000,) (700, 20) (700,)
# 2021-02-05 22:59:16.201153: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 22:59:16.202331: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-05 22:59:16.255705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:16.256297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-05 22:59:16.256365: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 22:59:16.496482: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-05 22:59:16.496616: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-05 22:59:16.614998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-05 22:59:16.630462: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-05 22:59:16.926001: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-05 22:59:16.981737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-05 22:59:17.491769: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-05 22:59:17.492007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:17.492739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:17.494891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-05 22:59:17.495443: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 22:59:17.495595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:17.496154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-02-05 22:59:17.496209: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 22:59:17.496247: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-02-05 22:59:17.496271: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-02-05 22:59:17.496294: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-02-05 22:59:17.496315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-02-05 22:59:17.496341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-02-05 22:59:17.496361: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-02-05 22:59:17.496382: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-02-05 22:59:17.496561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:17.497194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:17.497778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-02-05 22:59:17.499662: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 22:59:21.506227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-02-05 22:59:21.506278: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-02-05 22:59:21.506293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-02-05 22:59:21.512345: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:21.513094: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:21.513698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-05 22:59:21.514214: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-02-05 22:59:21.514264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13960 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# 2021-02-05 22:59:21.763244: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-05 22:59:21.771321: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/50
# 2021-02-05 22:59:22.163741: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 22/22 [==============================] - 2s 19ms/step - loss: nan - accuracy: 0.1965 - val_loss: nan - val_accuracy: 0.2000
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2095 - val_loss: nan - val_accuracy: 0.2000
# Epoch 3/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2044 - val_loss: nan - val_accuracy: 0.2000
# Epoch 4/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2064 - val_loss: nan - val_accuracy: 0.2000
# Epoch 5/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1991 - val_loss: nan - val_accuracy: 0.2000
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 7/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 8/50
# 22/22 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.1983 - val_loss: nan - val_accuracy: 0.2000
# Epoch 9/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2251 - val_loss: nan - val_accuracy: 0.2000
# Epoch 10/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1996 - val_loss: nan - val_accuracy: 0.2000
# Epoch 11/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2130 - val_loss: nan - val_accuracy: 0.2000
# Epoch 12/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1880 - val_loss: nan - val_accuracy: 0.2000
# Epoch 13/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.1935 - val_loss: nan - val_accuracy: 0.2000
# Epoch 14/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1900 - val_loss: nan - val_accuracy: 0.2000
# Epoch 15/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2188 - val_loss: nan - val_accuracy: 0.2000
# Epoch 16/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2068 - val_loss: nan - val_accuracy: 0.2000
# Epoch 17/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1954 - val_loss: nan - val_accuracy: 0.2000
# Epoch 18/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 19/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2119 - val_loss: nan - val_accuracy: 0.2000
# Epoch 20/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1883 - val_loss: nan - val_accuracy: 0.2000
# Epoch 21/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1910 - val_loss: nan - val_accuracy: 0.2000
# Epoch 22/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2256 - val_loss: nan - val_accuracy: 0.2000
# Epoch 23/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2151 - val_loss: nan - val_accuracy: 0.2000
# Epoch 24/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2226 - val_loss: nan - val_accuracy: 0.2000
# Epoch 25/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2288 - val_loss: nan - val_accuracy: 0.2000
# Epoch 26/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1942 - val_loss: nan - val_accuracy: 0.2000
# Epoch 27/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2106 - val_loss: nan - val_accuracy: 0.2000
# Epoch 28/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 29/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2154 - val_loss: nan - val_accuracy: 0.2000
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2003 - val_loss: nan - val_accuracy: 0.2000
# Epoch 31/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2036 - val_loss: nan - val_accuracy: 0.2000
# Epoch 32/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2041 - val_loss: nan - val_accuracy: 0.2000
# Epoch 33/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1764 - val_loss: nan - val_accuracy: 0.2000
# Epoch 34/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2166 - val_loss: nan - val_accuracy: 0.2000
# Epoch 35/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2101 - val_loss: nan - val_accuracy: 0.2000
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1899 - val_loss: nan - val_accuracy: 0.2000
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1916 - val_loss: nan - val_accuracy: 0.2000
# Epoch 38/50
# 22/22 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.1857 - val_loss: nan - val_accuracy: 0.2000
# Epoch 39/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2224 - val_loss: nan - val_accuracy: 0.2000
# Epoch 40/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1940 - val_loss: nan - val_accuracy: 0.2000
# Epoch 41/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.1976 - val_loss: nan - val_accuracy: 0.2000
# Epoch 42/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2084 - val_loss: nan - val_accuracy: 0.2000
# Epoch 43/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1775 - val_loss: nan - val_accuracy: 0.2000
# Epoch 44/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1927 - val_loss: nan - val_accuracy: 0.2000
# Epoch 45/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2059 - val_loss: nan - val_accuracy: 0.2000
# Epoch 46/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1951 - val_loss: nan - val_accuracy: 0.2000
# Epoch 47/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2195 - val_loss: nan - val_accuracy: 0.2000
# Epoch 48/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1969 - val_loss: nan - val_accuracy: 0.2000
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1901 - val_loss: nan - val_accuracy: 0.2000
# Epoch 50/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1911 - val_loss: nan - val_accuracy: 0.2000
# Epoch 1/50
# 22/22 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.2015 - val_loss: nan - val_accuracy: 0.2000
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2095 - val_loss: nan - val_accuracy: 0.2000
# Epoch 3/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2044 - val_loss: nan - val_accuracy: 0.2000
# Epoch 4/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2064 - val_loss: nan - val_accuracy: 0.2000
# Epoch 5/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1991 - val_loss: nan - val_accuracy: 0.2000
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 7/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 8/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1983 - val_loss: nan - val_accuracy: 0.2000
# Epoch 9/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2251 - val_loss: nan - val_accuracy: 0.2000
# Epoch 10/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1996 - val_loss: nan - val_accuracy: 0.2000
# Epoch 11/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2130 - val_loss: nan - val_accuracy: 0.2000
# Epoch 12/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1880 - val_loss: nan - val_accuracy: 0.2000
# Epoch 13/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1935 - val_loss: nan - val_accuracy: 0.2000
# Epoch 14/50
# 22/22 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.1900 - val_loss: nan - val_accuracy: 0.2000
# Epoch 15/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.2188 - val_loss: nan - val_accuracy: 0.2000
# Epoch 16/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2068 - val_loss: nan - val_accuracy: 0.2000
# Epoch 17/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1954 - val_loss: nan - val_accuracy: 0.2000
# Epoch 18/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 19/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2119 - val_loss: nan - val_accuracy: 0.2000
# Epoch 20/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1883 - val_loss: nan - val_accuracy: 0.2000
# Epoch 21/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1910 - val_loss: nan - val_accuracy: 0.2000
# Epoch 22/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2256 - val_loss: nan - val_accuracy: 0.2000
# Epoch 23/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2151 - val_loss: nan - val_accuracy: 0.2000
# Epoch 24/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2226 - val_loss: nan - val_accuracy: 0.2000
# Epoch 25/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2288 - val_loss: nan - val_accuracy: 0.2000
# Epoch 26/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1942 - val_loss: nan - val_accuracy: 0.2000
# Epoch 27/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2106 - val_loss: nan - val_accuracy: 0.2000
# Epoch 28/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 29/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2154 - val_loss: nan - val_accuracy: 0.2000
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2003 - val_loss: nan - val_accuracy: 0.2000
# Epoch 31/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2036 - val_loss: nan - val_accuracy: 0.2000
# Epoch 32/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2041 - val_loss: nan - val_accuracy: 0.2000
# Epoch 33/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.1764 - val_loss: nan - val_accuracy: 0.2000
# Epoch 34/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2166 - val_loss: nan - val_accuracy: 0.2000
# Epoch 35/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2101 - val_loss: nan - val_accuracy: 0.2000
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1899 - val_loss: nan - val_accuracy: 0.2000
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1916 - val_loss: nan - val_accuracy: 0.2000
# Epoch 38/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1857 - val_loss: nan - val_accuracy: 0.2000
# Epoch 39/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2224 - val_loss: nan - val_accuracy: 0.2000
# Epoch 40/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1940 - val_loss: nan - val_accuracy: 0.2000
# Epoch 41/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1976 - val_loss: nan - val_accuracy: 0.2000
# Epoch 42/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.2084 - val_loss: nan - val_accuracy: 0.2000
# Epoch 43/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1775 - val_loss: nan - val_accuracy: 0.2000
# Epoch 44/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1927 - val_loss: nan - val_accuracy: 0.2000
# Epoch 45/50
# 22/22 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.2059 - val_loss: nan - val_accuracy: 0.2000
# Epoch 46/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1951 - val_loss: nan - val_accuracy: 0.2000
# Epoch 47/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2195 - val_loss: nan - val_accuracy: 0.2000
# Epoch 48/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1969 - val_loss: nan - val_accuracy: 0.2000
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1901 - val_loss: nan - val_accuracy: 0.2000
# Epoch 50/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1911 - val_loss: nan - val_accuracy: 0.2000
# Epoch 1/50
# 22/22 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.2066 - val_loss: nan - val_accuracy: 0.2000
# Epoch 2/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2095 - val_loss: nan - val_accuracy: 0.2000
# Epoch 3/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2044 - val_loss: nan - val_accuracy: 0.2000
# Epoch 4/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2064 - val_loss: nan - val_accuracy: 0.2000
# Epoch 5/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1991 - val_loss: nan - val_accuracy: 0.2000
# Epoch 6/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 7/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2129 - val_loss: nan - val_accuracy: 0.2000
# Epoch 8/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1983 - val_loss: nan - val_accuracy: 0.2000
# Epoch 9/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2251 - val_loss: nan - val_accuracy: 0.2000
# Epoch 10/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1996 - val_loss: nan - val_accuracy: 0.2000
# Epoch 11/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2130 - val_loss: nan - val_accuracy: 0.2000
# Epoch 12/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1880 - val_loss: nan - val_accuracy: 0.2000
# Epoch 13/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1935 - val_loss: nan - val_accuracy: 0.2000
# Epoch 14/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1900 - val_loss: nan - val_accuracy: 0.2000
# Epoch 15/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2188 - val_loss: nan - val_accuracy: 0.2000
# Epoch 16/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2068 - val_loss: nan - val_accuracy: 0.2000
# Epoch 17/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1954 - val_loss: nan - val_accuracy: 0.2000
# Epoch 18/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 19/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2119 - val_loss: nan - val_accuracy: 0.2000
# Epoch 20/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1883 - val_loss: nan - val_accuracy: 0.2000
# Epoch 21/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1910 - val_loss: nan - val_accuracy: 0.2000
# Epoch 22/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2256 - val_loss: nan - val_accuracy: 0.2000
# Epoch 23/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2151 - val_loss: nan - val_accuracy: 0.2000
# Epoch 24/50
# 22/22 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.2226 - val_loss: nan - val_accuracy: 0.2000
# Epoch 25/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2288 - val_loss: nan - val_accuracy: 0.2000
# Epoch 26/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1942 - val_loss: nan - val_accuracy: 0.2000
# Epoch 27/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2106 - val_loss: nan - val_accuracy: 0.2000
# Epoch 28/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2025 - val_loss: nan - val_accuracy: 0.2000
# Epoch 29/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2154 - val_loss: nan - val_accuracy: 0.2000
# Epoch 30/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2003 - val_loss: nan - val_accuracy: 0.2000
# Epoch 31/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2036 - val_loss: nan - val_accuracy: 0.2000
# Epoch 32/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2041 - val_loss: nan - val_accuracy: 0.2000
# Epoch 33/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1764 - val_loss: nan - val_accuracy: 0.2000
# Epoch 34/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2166 - val_loss: nan - val_accuracy: 0.2000
# Epoch 35/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2101 - val_loss: nan - val_accuracy: 0.2000
# Epoch 36/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1899 - val_loss: nan - val_accuracy: 0.2000
# Epoch 37/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1916 - val_loss: nan - val_accuracy: 0.2000
# Epoch 38/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1857 - val_loss: nan - val_accuracy: 0.2000
# Epoch 39/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2224 - val_loss: nan - val_accuracy: 0.2000
# Epoch 40/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1940 - val_loss: nan - val_accuracy: 0.2000
# Epoch 41/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1976 - val_loss: nan - val_accuracy: 0.2000
# Epoch 42/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2084 - val_loss: nan - val_accuracy: 0.2000
# Epoch 43/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1775 - val_loss: nan - val_accuracy: 0.2000
# Epoch 44/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1927 - val_loss: nan - val_accuracy: 0.2000
# Epoch 45/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2059 - val_loss: nan - val_accuracy: 0.2000
# Epoch 46/50
# 22/22 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.1951 - val_loss: nan - val_accuracy: 0.2000
# Epoch 47/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.2195 - val_loss: nan - val_accuracy: 0.2000
# Epoch 48/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1969 - val_loss: nan - val_accuracy: 0.2000
# Epoch 49/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1901 - val_loss: nan - val_accuracy: 0.2000
# Epoch 50/50
# 22/22 [==============================] - 0s 4ms/step - loss: nan - accuracy: 0.1911 - val_loss: nan - val_accuracy: 0.2000
# evaluation result CORRECT

# %% [markdown]
# # **Ejercicio 3: DNN regression**  <a name="eje2"></a>
#
# Vamos a utilizar ahora las DNN para resolver problemas de regresión. La principal diferencia en estas arquitecturas esta en la capa de salida. En este caso solo debemos tener una neurona sin activación que nos permita dar una respuesta en terminos de la escala de los datos. Implemente una función que.
#
# - Carge los datos de _Boston house price prediction_ que están en [`sklearn`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_boston). Utilice la información de tamaño de las caracteristicas para definir la capa inicial. **NO haremos partición de los datos en train y test**
#
# - Cree una red neuronal que reciba en la capa de entrada **todas las caracteristicas del dataset** y además tenga tres capas intermedias de 64, 32, 10 neuronas, respectivamente. Las activaciones para la capa intermedia debe ser tangente hiperpolica.
#
# - Las redes neuronal deben ser entrenada con unpitimizador RMSprop,  epochs=50,  batch_size=32, y regla de minimización: `'mse'` y metrica de evaluación `'mse'`
#
# - La función debe retornar: los valores originales de $y$, los valores estimados de $y$ y el  modelo entrenado

# %%
#@title **2172969**
#@markdown No modifique las dos últimas lineas

def fun_53012821():
  import numpy as np
  from sklearn.datasets import load_boston
  import tensorflow as tf
  from tensorflow import keras
  X, y = load_boston(return_X_y=True)

  dnnr = keras.models.Sequential([
                                    keras.layers.Flatten( input_shape= (X[0].shape)),
                                    keras.layers.Dense(64, activation=tf.nn.tanh),
                                    keras.layers.Dense(32, activation=tf.nn.tanh),
                                    keras.layers.Dense(10, activation=tf.nn.tanh),
                                    keras.layers.Dense(1)
                                    ])
  dnnr.compile(optimizer=tf.keras.optimizers.RMSprop(), 
              loss='MSE',
              metrics=['mean_squared_error'])
  dnnr.fit(X, y, epochs=50, batch_size=32)
  yest = dnnr.predict(X)
  #yest = np.argmax(yest, axis = 1) 
  return y, yest, dnnr


import urllib.parse, inspect
src53012821 = urllib.parse.quote_plus(inspect.getsource(fun_53012821))

# %%
#@title **verifique su respuesta**
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras


tf.random.set_seed(23)
np.random.seed(23)

y, yest, dnnr= fun_53012821()
plt.plot(yest, label='estimado');
plt.plot(y, label='real');
plt.legend(); plt.show()
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 1ms/step - loss: 520.6168 - mean_squared_error: 520.6168
# Epoch 2/50
# 16/16 [==============================] - 0s 1ms/step - loss: 431.8872 - mean_squared_error: 431.8872
# Epoch 3/50
# 16/16 [==============================] - 0s 1ms/step - loss: 423.2855 - mean_squared_error: 423.2855
# Epoch 4/50
# 16/16 [==============================] - 0s 1ms/step - loss: 411.0282 - mean_squared_error: 411.0282
# Epoch 5/50
# 16/16 [==============================] - 0s 1ms/step - loss: 425.7497 - mean_squared_error: 425.7497
# Epoch 6/50
# 16/16 [==============================] - 0s 1ms/step - loss: 416.1094 - mean_squared_error: 416.1094
# Epoch 7/50
# 16/16 [==============================] - 0s 1ms/step - loss: 360.4171 - mean_squared_error: 360.4171
# Epoch 8/50
# 16/16 [==============================] - 0s 1ms/step - loss: 374.2493 - mean_squared_error: 374.2493
# Epoch 9/50
# 16/16 [==============================] - 0s 1ms/step - loss: 389.8791 - mean_squared_error: 389.8791
# Epoch 10/50
# 16/16 [==============================] - 0s 1ms/step - loss: 373.4504 - mean_squared_error: 373.4504
# Epoch 11/50
# 16/16 [==============================] - 0s 1ms/step - loss: 358.4573 - mean_squared_error: 358.4573
# Epoch 12/50
# 16/16 [==============================] - 0s 1ms/step - loss: 357.7705 - mean_squared_error: 357.7705
# Epoch 13/50
# 16/16 [==============================] - 0s 1ms/step - loss: 347.6122 - mean_squared_error: 347.6122
# Epoch 14/50
# 16/16 [==============================] - 0s 1ms/step - loss: 336.3647 - mean_squared_error: 336.3647
# Epoch 15/50
# 16/16 [==============================] - 0s 2ms/step - loss: 360.8746 - mean_squared_error: 360.8746
# Epoch 16/50
# 16/16 [==============================] - 0s 1ms/step - loss: 385.4300 - mean_squared_error: 385.4300
# Epoch 17/50
# 16/16 [==============================] - 0s 1ms/step - loss: 346.2843 - mean_squared_error: 346.2843
# Epoch 18/50
# 16/16 [==============================] - 0s 2ms/step - loss: 354.1468 - mean_squared_error: 354.1468
# Epoch 19/50
# 16/16 [==============================] - 0s 1ms/step - loss: 312.1277 - mean_squared_error: 312.1277
# Epoch 20/50
# 16/16 [==============================] - 0s 1ms/step - loss: 334.7921 - mean_squared_error: 334.7921
# Epoch 21/50
# 16/16 [==============================] - 0s 1ms/step - loss: 315.1891 - mean_squared_error: 315.1891
# Epoch 22/50
# 16/16 [==============================] - 0s 1ms/step - loss: 305.6973 - mean_squared_error: 305.6973
# Epoch 23/50
# 16/16 [==============================] - 0s 1ms/step - loss: 297.3664 - mean_squared_error: 297.3664
# Epoch 24/50
# 16/16 [==============================] - 0s 1ms/step - loss: 293.3684 - mean_squared_error: 293.3684
# Epoch 25/50
# 16/16 [==============================] - 0s 1ms/step - loss: 290.3136 - mean_squared_error: 290.3136
# Epoch 26/50
# 16/16 [==============================] - 0s 1ms/step - loss: 294.1467 - mean_squared_error: 294.1467
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 288.8674 - mean_squared_error: 288.8674
# Epoch 28/50
# 16/16 [==============================] - 0s 2ms/step - loss: 268.8948 - mean_squared_error: 268.8948
# Epoch 29/50
# 16/16 [==============================] - 0s 1ms/step - loss: 260.4595 - mean_squared_error: 260.4595
# Epoch 30/50
# 16/16 [==============================] - 0s 2ms/step - loss: 252.3483 - mean_squared_error: 252.3483
# Epoch 31/50
# 16/16 [==============================] - 0s 1ms/step - loss: 265.0634 - mean_squared_error: 265.0634
# Epoch 32/50
# 16/16 [==============================] - 0s 1ms/step - loss: 253.7133 - mean_squared_error: 253.7133
# Epoch 33/50
# 16/16 [==============================] - 0s 1ms/step - loss: 234.4315 - mean_squared_error: 234.4315
# Epoch 34/50
# 16/16 [==============================] - 0s 1ms/step - loss: 261.7187 - mean_squared_error: 261.7187
# Epoch 35/50
# 16/16 [==============================] - 0s 2ms/step - loss: 253.4019 - mean_squared_error: 253.4019
# Epoch 36/50
# 16/16 [==============================] - 0s 2ms/step - loss: 267.2239 - mean_squared_error: 267.2239
# Epoch 37/50
# 16/16 [==============================] - 0s 1ms/step - loss: 279.3955 - mean_squared_error: 279.3955
# Epoch 38/50
# 16/16 [==============================] - 0s 1ms/step - loss: 237.4222 - mean_squared_error: 237.4222
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 242.2047 - mean_squared_error: 242.2047
# Epoch 40/50
# 16/16 [==============================] - 0s 1ms/step - loss: 216.5869 - mean_squared_error: 216.5869
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 237.9659 - mean_squared_error: 237.9659
# Epoch 42/50
# 16/16 [==============================] - 0s 1ms/step - loss: 199.6666 - mean_squared_error: 199.6666
# Epoch 43/50
# 16/16 [==============================] - 0s 1ms/step - loss: 217.0935 - mean_squared_error: 217.0935
# Epoch 44/50
# 16/16 [==============================] - 0s 2ms/step - loss: 207.1932 - mean_squared_error: 207.1932
# Epoch 45/50
# 16/16 [==============================] - 0s 2ms/step - loss: 221.0361 - mean_squared_error: 221.0361
# Epoch 46/50
# 16/16 [==============================] - 0s 1ms/step - loss: 197.5335 - mean_squared_error: 197.5335
# Epoch 47/50
# 16/16 [==============================] - 0s 1ms/step - loss: 202.4263 - mean_squared_error: 202.4263
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 212.7402 - mean_squared_error: 212.7402
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 187.3843 - mean_squared_error: 187.3843
# Epoch 50/50
# 16/16 [==============================] - 0s 2ms/step - loss: 197.7185 - mean_squared_error: 197.7185

# %%
#@title **Evalue su respuesta.**
# !./run CHECK_SOLUTION PS5_53012821 $src53012821
# Out:
# 2021-02-05 16:19:45.212167: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-02-05 16:19:47.222789: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 16:19:47.224215: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-05 16:19:47.234903: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-02-05 16:19:47.234945: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (2f529d491295): /proc/driver/nvidia/version does not exist
# 2021-02-05 16:19:47.235394: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-05 16:19:47.344141: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-02-05 16:19:47.344565: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# Epoch 1/50
# 16/16 [==============================] - 1s 2ms/step - loss: 520.6168 - mean_squared_error: 520.6168
# Epoch 2/50
# 16/16 [==============================] - 0s 1ms/step - loss: 431.8872 - mean_squared_error: 431.8872
# Epoch 3/50
# 16/16 [==============================] - 0s 948us/step - loss: 423.2855 - mean_squared_error: 423.2855
# Epoch 4/50
# 16/16 [==============================] - 0s 920us/step - loss: 411.0282 - mean_squared_error: 411.0282
# Epoch 5/50
# 16/16 [==============================] - 0s 933us/step - loss: 425.7497 - mean_squared_error: 425.7497
# Epoch 6/50
# 16/16 [==============================] - 0s 954us/step - loss: 416.1094 - mean_squared_error: 416.1094
# Epoch 7/50
# 16/16 [==============================] - 0s 922us/step - loss: 360.4171 - mean_squared_error: 360.4171
# Epoch 8/50
# 16/16 [==============================] - 0s 937us/step - loss: 374.2493 - mean_squared_error: 374.2493
# Epoch 9/50
# 16/16 [==============================] - 0s 952us/step - loss: 389.8791 - mean_squared_error: 389.8791
# Epoch 10/50
# 16/16 [==============================] - 0s 903us/step - loss: 373.4504 - mean_squared_error: 373.4504
# Epoch 11/50
# 16/16 [==============================] - 0s 944us/step - loss: 358.4573 - mean_squared_error: 358.4573
# Epoch 12/50
# 16/16 [==============================] - 0s 986us/step - loss: 357.7705 - mean_squared_error: 357.7705
# Epoch 13/50
# 16/16 [==============================] - 0s 1ms/step - loss: 347.6122 - mean_squared_error: 347.6122
# Epoch 14/50
# 16/16 [==============================] - 0s 966us/step - loss: 336.3647 - mean_squared_error: 336.3647
# Epoch 15/50
# 16/16 [==============================] - 0s 1ms/step - loss: 360.8746 - mean_squared_error: 360.8746
# Epoch 16/50
# 16/16 [==============================] - 0s 962us/step - loss: 385.4300 - mean_squared_error: 385.4300
# Epoch 17/50
# 16/16 [==============================] - 0s 924us/step - loss: 346.2843 - mean_squared_error: 346.2843
# Epoch 18/50
# 16/16 [==============================] - 0s 1ms/step - loss: 354.1468 - mean_squared_error: 354.1468
# Epoch 19/50
# 16/16 [==============================] - 0s 971us/step - loss: 312.1277 - mean_squared_error: 312.1277
# Epoch 20/50
# 16/16 [==============================] - 0s 902us/step - loss: 334.7921 - mean_squared_error: 334.7921
# Epoch 21/50
# 16/16 [==============================] - 0s 916us/step - loss: 315.1891 - mean_squared_error: 315.1891
# Epoch 22/50
# 16/16 [==============================] - 0s 929us/step - loss: 305.6973 - mean_squared_error: 305.6973
# Epoch 23/50
# 16/16 [==============================] - 0s 1ms/step - loss: 297.3664 - mean_squared_error: 297.3664
# Epoch 24/50
# 16/16 [==============================] - 0s 1ms/step - loss: 293.3684 - mean_squared_error: 293.3684
# Epoch 25/50
# 16/16 [==============================] - 0s 922us/step - loss: 290.3136 - mean_squared_error: 290.3136
# Epoch 26/50
# 16/16 [==============================] - 0s 960us/step - loss: 294.1467 - mean_squared_error: 294.1467
# Epoch 27/50
# 16/16 [==============================] - 0s 1ms/step - loss: 288.8674 - mean_squared_error: 288.8674
# Epoch 28/50
# 16/16 [==============================] - 0s 945us/step - loss: 268.8948 - mean_squared_error: 268.8948
# Epoch 29/50
# 16/16 [==============================] - 0s 1ms/step - loss: 260.4595 - mean_squared_error: 260.4595
# Epoch 30/50
# 16/16 [==============================] - 0s 1ms/step - loss: 252.3483 - mean_squared_error: 252.3483
# Epoch 31/50
# 16/16 [==============================] - 0s 919us/step - loss: 265.0634 - mean_squared_error: 265.0634
# Epoch 32/50
# 16/16 [==============================] - 0s 910us/step - loss: 253.7133 - mean_squared_error: 253.7133
# Epoch 33/50
# 16/16 [==============================] - 0s 909us/step - loss: 234.4315 - mean_squared_error: 234.4315
# Epoch 34/50
# 16/16 [==============================] - 0s 925us/step - loss: 261.7187 - mean_squared_error: 261.7187
# Epoch 35/50
# 16/16 [==============================] - 0s 917us/step - loss: 253.4019 - mean_squared_error: 253.4019
# Epoch 36/50
# 16/16 [==============================] - 0s 1ms/step - loss: 267.2239 - mean_squared_error: 267.2239
# Epoch 37/50
# 16/16 [==============================] - 0s 883us/step - loss: 279.3955 - mean_squared_error: 279.3955
# Epoch 38/50
# 16/16 [==============================] - 0s 1ms/step - loss: 237.4222 - mean_squared_error: 237.4222
# Epoch 39/50
# 16/16 [==============================] - 0s 1ms/step - loss: 242.2047 - mean_squared_error: 242.2047
# Epoch 40/50
# 16/16 [==============================] - 0s 1ms/step - loss: 216.5869 - mean_squared_error: 216.5869
# Epoch 41/50
# 16/16 [==============================] - 0s 1ms/step - loss: 237.9659 - mean_squared_error: 237.9659
# Epoch 42/50
# 16/16 [==============================] - 0s 1ms/step - loss: 199.6666 - mean_squared_error: 199.6666
# Epoch 43/50
# 16/16 [==============================] - 0s 1ms/step - loss: 217.0935 - mean_squared_error: 217.0935
# Epoch 44/50
# 16/16 [==============================] - 0s 1ms/step - loss: 207.1932 - mean_squared_error: 207.1932
# Epoch 45/50
# 16/16 [==============================] - 0s 1ms/step - loss: 221.0361 - mean_squared_error: 221.0361
# Epoch 46/50
# 16/16 [==============================] - 0s 1ms/step - loss: 197.5335 - mean_squared_error: 197.5335
# Epoch 47/50
# 16/16 [==============================] - 0s 1ms/step - loss: 202.4263 - mean_squared_error: 202.4263
# Epoch 48/50
# 16/16 [==============================] - 0s 1ms/step - loss: 212.7402 - mean_squared_error: 212.7402
# Epoch 49/50
# 16/16 [==============================] - 0s 1ms/step - loss: 187.3843 - mean_squared_error: 187.3843
# Epoch 50/50
# 16/16 [==============================] - 0s 1ms/step - loss: 197.7185 - mean_squared_error: 197.7185
# evaluation result CORRECT

# %% [markdown]
# # **Pasos Finales.**

# %% [markdown]
# #### 1. Reemplace la variable con su código de estudiante

# %%
#@title **1. Complete la siguiente información:**
taller_name = "Taller_std_05_20202" #@param {type:"string"}
codigo_name = "tl5_21729" #@param {type:"string"}


import urllib.parse, inspect
taller = urllib.parse.quote_plus(taller_name)
codigo = urllib.parse.quote_plus(codigo_name)

print(taller, codigo)
# Out:
# Taller_prof_02_20202 tl2_12345

# %%
#@title **2. Guarde los cambios del taller**
# %%javascript
require(["base/js/namespace"],function(Jupyter) {
    Jupyter.notebook.save_checkpoint();
});

# %%
#@title **3. Ejecute la siguiente celda y envíe el archivo**
# !./convert_ipynb.sh $codigo $taller
# Out:
# uno: tl2_12345 dos Taller_prof_02_20202
# ¡PERFECTO!, el archivo   'tl2_12345.ipynb'   se creó correctamente :D

# %% [markdown]
# ---
# <img src="https://gitlab.com/bivl2ab/academico/cursos-uis/ai/ai-uis-student/raw/master/imgs/bannerThanks.jpg" alt="Drawing" style="width:700px;"/>
